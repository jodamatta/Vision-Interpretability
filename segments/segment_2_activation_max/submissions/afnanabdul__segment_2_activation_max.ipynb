# %% [markdown]
# <a href="https://colab.research.google.com/github/AfnanAbdul/Vision-Interpretability/blob/main/segments/segment_2_activation_max/submissions/afnanabdul__segment_2_activation_max.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Feature visualization: Activation Maximization
# Using Lucent Library https://lucent.readthedocs.io/en/latest/index.html to get the activation maximization visualizations like in the Circuits thread for the first 10 neurons of Mixed4a Layer of InceptionV1

# %%
# !pip install -q torch-lucent
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.5/253.5 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.0 MB/s eta 0:00:00
#   Building wheel for docopt (setup.py) ... done

# %%
from lucent.optvis import render, param, transform, objectives
from lucent.misc.io import show
from lucent.modelzoo import inceptionv1
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda') if torch.cuda.is_available() else 'cpu'

# %%
model = inceptionv1(pretrained=True)
model.to(device).eval()
# Out:
# InceptionV1(
#   (conv2d0_pre_relu_conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2))
#   (conv2d1_pre_relu_conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (conv2d2_pre_relu_conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1))
#   (mixed3a_1x1_pre_relu_conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#   (mixed3a_3x3_bottleneck_pre_relu_conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#   (mixed3a_5x5_bottleneck_pre_relu_conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1))
#   (mixed3a_pool_reduce_pre_relu_conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#   (mixed3a_3x3_pre_relu_conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1))
#   (mixed3a_5x5_pre_relu_conv): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#   (mixed3b_1x1_pre_relu_conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#   (mixed3b_3x3_bottleneck_pre_relu_conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#   (mixed3b_5x5_bottleneck_pre_relu_conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#   (mixed3b_pool_reduce_pre_relu_conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#   (mixed3b_3x3_pre_relu_conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1))
#   (mixed3b_5x5_pre_relu_conv): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1))
#   (mixed4a_1x1_pre_relu_conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4a_3x3_bottleneck_pre_relu_conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4a_5x5_bottleneck_pre_relu_conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4a_pool_reduce_pre_relu_conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4a_3x3_pre_relu_conv): Conv2d(96, 204, kernel_size=(3, 3), stride=(1, 1))
#   (mixed4a_5x5_pre_relu_conv): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1))
#   (mixed4b_1x1_pre_relu_conv): Conv2d(508, 160, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4b_3x3_bottleneck_pre_relu_conv): Conv2d(508, 112, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4b_5x5_bottleneck_pre_relu_conv): Conv2d(508, 24, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4b_pool_reduce_pre_relu_conv): Conv2d(508, 64, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4b_3x3_pre_relu_conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1))
#   (mixed4b_5x5_pre_relu_conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1))
#   (mixed4c_1x1_pre_relu_conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4c_3x3_bottleneck_pre_relu_conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4c_5x5_bottleneck_pre_relu_conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4c_pool_reduce_pre_relu_conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4c_3x3_pre_relu_conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   (mixed4c_5x5_pre_relu_conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1))
#   (mixed4d_1x1_pre_relu_conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4d_3x3_bottleneck_pre_relu_conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4d_5x5_bottleneck_pre_relu_conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4d_pool_reduce_pre_relu_conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4d_3x3_pre_relu_conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1))
#   (mixed4d_5x5_pre_relu_conv): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (mixed4e_1x1_pre_relu_conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4e_3x3_bottleneck_pre_relu_conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4e_5x5_bottleneck_pre_relu_conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4e_pool_reduce_pre_relu_conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#   (mixed4e_3x3_pre_relu_conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1))
#   (mixed4e_5x5_pre_relu_conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1))
#   (mixed5a_1x1_pre_relu_conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1))
#   (mixed5a_3x3_bottleneck_pre_relu_conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1))
#   (mixed5a_5x5_bottleneck_pre_relu_conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1))
#   (mixed5a_pool_reduce_pre_relu_conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#   (mixed5a_3x3_pre_relu_conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1))
#   (mixed5a_5x5_pre_relu_conv): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1))
#   (mixed5b_1x1_pre_relu_conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1))
#   (mixed5b_3x3_bottleneck_pre_relu_conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1))
#   (mixed5b_5x5_bottleneck_pre_relu_conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1))
#   (mixed5b_pool_reduce_pre_relu_conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#   (mixed5b_3x3_pre_relu_conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1))
#   (mixed5b_5x5_pre_relu_conv): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1))
#   (softmax2_pre_activation_matmul): Linear(in_features=1024, out_features=1008, bias=True)
#   (conv2d0): RedirectedReluLayer()
#   (maxpool0): MaxPool2dLayer()
#   (conv2d1): RedirectedReluLayer()
#   (conv2d2): RedirectedReluLayer()
#   (maxpool1): MaxPool2dLayer()
#   (mixed3a_pool): MaxPool2dLayer()
#   (mixed3a_1x1): RedirectedReluLayer()
#   (mixed3a_3x3_bottleneck): RedirectedReluLayer()
#   (mixed3a_5x5_bottleneck): RedirectedReluLayer()
#   (mixed3a_pool_reduce): RedirectedReluLayer()
#   (mixed3a_3x3): RedirectedReluLayer()
#   (mixed3a_5x5): RedirectedReluLayer()
#   (mixed3a): CatLayer()
#   (mixed3b_pool): MaxPool2dLayer()
#   (mixed3b_1x1): RedirectedReluLayer()
#   (mixed3b_3x3_bottleneck): RedirectedReluLayer()
#   (mixed3b_5x5_bottleneck): RedirectedReluLayer()
#   (mixed3b_pool_reduce): RedirectedReluLayer()
#   (mixed3b_3x3): RedirectedReluLayer()
#   (mixed3b_5x5): RedirectedReluLayer()
#   (mixed3b): CatLayer()
#   (maxpool4): MaxPool2dLayer()
#   (mixed4a_pool): MaxPool2dLayer()
#   (mixed4a_1x1): RedirectedReluLayer()
#   (mixed4a_3x3_bottleneck): RedirectedReluLayer()
#   (mixed4a_5x5_bottleneck): RedirectedReluLayer()
#   (mixed4a_pool_reduce): RedirectedReluLayer()
#   (mixed4a_3x3): RedirectedReluLayer()
#   (mixed4a_5x5): RedirectedReluLayer()
#   (mixed4a): CatLayer()
#   (mixed4b_pool): MaxPool2dLayer()
#   (mixed4b_1x1): RedirectedReluLayer()
#   (mixed4b_3x3_bottleneck): RedirectedReluLayer()
#   (mixed4b_5x5_bottleneck): RedirectedReluLayer()
#   (mixed4b_pool_reduce): RedirectedReluLayer()
#   (mixed4b_3x3): RedirectedReluLayer()
#   (mixed4b_5x5): RedirectedReluLayer()
#   (mixed4b): CatLayer()
#   (mixed4c_pool): MaxPool2dLayer()
#   (mixed4c_1x1): RedirectedReluLayer()
#   (mixed4c_3x3_bottleneck): RedirectedReluLayer()
#   (mixed4c_5x5_bottleneck): RedirectedReluLayer()
#   (mixed4c_pool_reduce): RedirectedReluLayer()
#   (mixed4c_3x3): RedirectedReluLayer()
#   (mixed4c_5x5): RedirectedReluLayer()
#   (mixed4c): CatLayer()
#   (mixed4d_pool): MaxPool2dLayer()
#   (mixed4d_1x1): RedirectedReluLayer()
#   (mixed4d_3x3_bottleneck): RedirectedReluLayer()
#   (mixed4d_5x5_bottleneck): RedirectedReluLayer()
#   (mixed4d_pool_reduce): RedirectedReluLayer()
#   (mixed4d_3x3): RedirectedReluLayer()
#   (mixed4d_5x5): RedirectedReluLayer()
#   (mixed4d): CatLayer()
#   (mixed4e_pool): MaxPool2dLayer()
#   (mixed4e_1x1): RedirectedReluLayer()
#   (mixed4e_3x3_bottleneck): RedirectedReluLayer()
#   (mixed4e_5x5_bottleneck): RedirectedReluLayer()
#   (mixed4e_pool_reduce): RedirectedReluLayer()
#   (mixed4e_3x3): RedirectedReluLayer()
#   (mixed4e_5x5): RedirectedReluLayer()
#   (mixed4e): CatLayer()
#   (maxpool10): MaxPool2dLayer()
#   (mixed5a_pool): MaxPool2dLayer()
#   (mixed5a_1x1): RedirectedReluLayer()
#   (mixed5a_3x3_bottleneck): RedirectedReluLayer()
#   (mixed5a_5x5_bottleneck): RedirectedReluLayer()
#   (mixed5a_pool_reduce): RedirectedReluLayer()
#   (mixed5a_3x3): RedirectedReluLayer()
#   (mixed5a_5x5): RedirectedReluLayer()
#   (mixed5a): CatLayer()
#   (mixed5b_pool): MaxPool2dLayer()
#   (mixed5b_1x1): RedirectedReluLayer()
#   (mixed5b_3x3_bottleneck): RedirectedReluLayer()
#   (mixed5b_5x5_bottleneck): RedirectedReluLayer()
#   (mixed5b_pool_reduce): RedirectedReluLayer()
#   (mixed5b_3x3): RedirectedReluLayer()
#   (mixed5b_5x5): RedirectedReluLayer()
#   (mixed5b): CatLayer()
#   (softmax2): SoftMaxLayer()
# )

# %%
images = []
for i in range(10):
    img = render.render_vis(model, objectives.channel("mixed4a", i))
    images.append(img[0])

show(images)
# Out:
# 100%|██████████| 512/512 [00:15<00:00, 33.23it/s]
# 100%|██████████| 512/512 [00:15<00:00, 33.84it/s]
# 100%|██████████| 512/512 [00:15<00:00, 32.30it/s]
# 100%|██████████| 512/512 [00:14<00:00, 34.22it/s]
# 100%|██████████| 512/512 [00:15<00:00, 34.10it/s]
# 100%|██████████| 512/512 [00:16<00:00, 31.56it/s]
# 100%|██████████| 512/512 [00:15<00:00, 33.06it/s]
# 100%|██████████| 512/512 [00:15<00:00, 33.89it/s]
# 100%|██████████| 512/512 [00:15<00:00, 33.86it/s]
# 100%|██████████| 512/512 [00:15<00:00, 32.06it/s]
# <div style="display: flex; flex-direction: row;"><div style="margin-right:10px; margin-top: 4px;">
#                             0 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             1 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             2 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             3 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             4 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             5 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             6 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             7 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             8 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div><div style="margin-right:10px; margin-top: 4px;">
#                             9 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div></div>
